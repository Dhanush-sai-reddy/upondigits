# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanush-sai-reddy/uponcv-csv/blob/main/Synapse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
parent_directory = os.path.dirname(SYNAPSE_DATASET_PATH)
SESSION2_PATH = os.path.join(parent_directory, "Session2")
SESSION3_PATH = os.path.join(parent_directory, "Session3")
print(f"SESSION2_PATH: {SESSION2_PATH}")
print(f"SESSION3_PATH: {SESSION3_PATH}")
# Out:
# SESSION2_PATH: /content/drive/MyDrive/Session2
# SESSION3_PATH: /content/drive/MyDrive/Session3

# %%
# !ls "{SESSION3_PATH}"
# Out:
# session3_subject_1   session3_subject_18  session3_subject_3
# session3_subject_10  session3_subject_19  session3_subject_4
# session3_subject_11  session3_subject_2   session3_subject_5
# session3_subject_12  session3_subject_20  session3_subject_6
# session3_subject_13  session3_subject_21  session3_subject_7
# session3_subject_14  session3_subject_22  session3_subject_8
# session3_subject_15  session3_subject_23  session3_subject_9
# session3_subject_16  session3_subject_24
# session3_subject_17  session3_subject_25

# %%
import os

sample_subject_path = os.path.join(SYNAPSE_DATASET_PATH, "session1_subject_1")
print(f"Listing contents of: {sample_subject_path}")
# !ls "{sample_subject_path}"
# Out:
# Listing contents of: /content/drive/MyDrive/Session1/session1_subject_1
# gesture00_trial01.csv  gesture01_trial06.csv  gesture03_trial04.csv
# gesture00_trial02.csv  gesture01_trial07.csv  gesture03_trial05.csv
# gesture00_trial03.csv  gesture02_trial01.csv  gesture03_trial06.csv
# gesture00_trial04.csv  gesture02_trial02.csv  gesture03_trial07.csv
# gesture00_trial05.csv  gesture02_trial03.csv  gesture04_trial01.csv
# gesture00_trial06.csv  gesture02_trial04.csv  gesture04_trial02.csv
# gesture00_trial07.csv  gesture02_trial05.csv  gesture04_trial03.csv
# gesture01_trial01.csv  gesture02_trial06.csv  gesture04_trial04.csv
# gesture01_trial02.csv  gesture02_trial07.csv  gesture04_trial05.csv
# gesture01_trial03.csv  gesture03_trial01.csv  gesture04_trial06.csv
# gesture01_trial04.csv  gesture03_trial02.csv  gesture04_trial07.csv
# gesture01_trial05.csv  gesture03_trial03.csv

# %%
import os

subject1_path = os.path.join(SESSION3_PATH, "session3_subject_1")
print(f"Listing contents of: {subject1_path}")
# !ls "{subject1_path}"
# Out:
# Listing contents of: /content/drive/MyDrive/Session3/session3_subject_1
# gesture00_trial01.csv  gesture01_trial06.csv  gesture03_trial04.csv
# gesture00_trial02.csv  gesture01_trial07.csv  gesture03_trial05.csv
# gesture00_trial03.csv  gesture02_trial01.csv  gesture03_trial06.csv
# gesture00_trial04.csv  gesture02_trial02.csv  gesture03_trial07.csv
# gesture00_trial05.csv  gesture02_trial03.csv  gesture04_trial01.csv
# gesture00_trial06.csv  gesture02_trial04.csv  gesture04_trial02.csv
# gesture00_trial07.csv  gesture02_trial05.csv  gesture04_trial03.csv
# gesture01_trial01.csv  gesture02_trial06.csv  gesture04_trial04.csv
# gesture01_trial02.csv  gesture02_trial07.csv  gesture04_trial05.csv
# gesture01_trial03.csv  gesture03_trial01.csv  gesture04_trial06.csv
# gesture01_trial04.csv  gesture03_trial02.csv  gesture04_trial07.csv
# gesture01_trial05.csv  gesture03_trial03.csv

# %%
import random

df = random.choice(all_dataframes)


df
# Out:
#            ch1       ch2       ch3       ch4       ch5       ch6       ch7  \
# 0     0.062781  0.075532  0.090062  0.075550  0.085540  0.049463  0.084480
# 1     0.013816  0.036262  0.051916  0.077630  0.058763  0.035000  0.021447
# 2     0.052389  0.063238  0.072680  0.071976  0.024078  0.018571  0.008775
# 3     0.010374  0.016467  0.042895  0.029639  0.005907 -0.005039 -0.009943
# 4    -0.010021 -0.017009 -0.014650 -0.030528 -0.018180 -0.017249 -0.005176
# ...        ...       ...       ...       ...       ...       ...       ...
# 2555  0.050296  0.080925  0.139874  0.087240  0.079044  0.040818  0.024183
# 2556  0.036303 -0.004560  0.069358  0.053994  0.053754  0.020267 -0.057791
# 2557 -0.006282  0.005280 -0.010033  0.049126  0.059894  0.036730 -0.046270
# 2558 -0.028216  0.020675 -0.052420 -0.035686 -0.000652  0.015972 -0.001760
# 2559 -0.026841 -0.032358 -0.071990 -0.143179 -0.103702 -0.064510  0.017641
#
#            ch8   session              subject              file_name
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(x=random_df.index, y=random_df['ch1'], data=random_df)
plt.title(f"Channel 1 (ch1) values for {session_info}/{subject_info}/{file_name_info}")
plt.xlabel("Serial Number (Data Point Index)")
plt.ylabel("Channel 1 (ch1) Value")
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(x=random_df.index, y=random_df['ch2'], data=random_df)
plt.title(f"Channel 1 (ch1) values for {session_info}/{subject_info}/{file_name_info}")
plt.xlabel("Serial Number (Data Point Index)")
plt.ylabel("Channel 1 (ch1) Value")
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
correlation_matrix = random_df[['ch1', 'ch2', 'ch3', 'ch4', 'ch5', 'ch6', 'ch7', 'ch8']].corr()
print("Correlation Matrix for the selected DataFrame:")
display(correlation_matrix)
# Out:
# Correlation Matrix for the selected DataFrame:
#           ch1       ch2       ch3       ch4       ch5       ch6       ch7  \
# ch1  1.000000  0.891314  0.723023  0.664485  0.820005  0.776140  0.534034
# ch2  0.891314  1.000000  0.885683  0.698364  0.783873  0.672583  0.413102
# ch3  0.723023  0.885683  1.000000  0.686815  0.693543  0.567084  0.331930
# ch4  0.664485  0.698364  0.686815  1.000000  0.832771  0.639653  0.360670
# ch5  0.820005  0.783873  0.693543  0.832771  1.000000  0.901395  0.562265
# ch6  0.776140  0.672583  0.567084  0.639653  0.901395  1.000000  0.788658
# ch7  0.534034  0.413102  0.331930  0.360670  0.562265  0.788658  1.000000
# ch8  0.836387  0.657728  0.513207  0.516988  0.704730  0.827174  0.747485
#
#           ch8
# ch1  0.836387
# ch2  0.657728
# ch3  0.513207
# ch4  0.516988
# ch5  0.704730
# ch6  0.827174
# ch7  0.747485
# ch8  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title(f"Correlation Matrix Heatmap for {session_info}/{subject_info}/{file_name_info}")
plt.show()

# %% [markdown]
# #so ch1-ch2 and ch1-ch5, ch1-ch6,ch1-ch8, and ch2-ch3,somewhat lets say ch5-ch2 and ch3-ch4,5(69) ,,,,and ch4-ch5 ,ch5-ch6,,ch6-7,ch 6-8,well kinda interconnected
